# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
from scipy.stats import norm, uniform
import numpy as np
import matplotlib.pyplot as plt
# Distribucion normal
def pdfnorm(x, media = 0, dstd = 1):
    resultado = norm.pdf(x = x, loc = media, scale = dstd)
    return resultado
def cdfnorm(x, media = 0, dstd = 1):
    resultado = norm.cdf(x = x,  loc = media, scale = dstd)
    return resultado
def ppfnorm(x, media = 0, dstd = 1):
    resultado = norm.ppf(q = x, loc = media, scale = dstd)
    return resultado
def rvsnorm(x, media = 0, dstd = 1):
    resultado = norm.rvs(size = x,  loc = media, scale = dstd)
    return resultado

# %%
media = 0
dstd = 1
datos = np.arange(-10, 10, 0.2)
pdf = pdfnorm(datos, media, dstd)
cdf = cdfnorm(datos, media, dstd)
ppf = ppfnorm(datos, media, dstd)
# Grafico PDF funcion de densidad de probabilidad
plt.subplot(2, 1, 1)
plt.xlabel("Datos de muestra")
plt.ylabel("Función de densidad de probabilidad")
plt.title("Función de densidad de probabilidad")
plt.plot(datos, pdf)
plt.show()
# Gráfico CDF funcion de distribución acumulada
plt.subplot(2, 1, 1)
plt.xlabel("Datos de muestra")
plt.ylabel("Función de distribución acumulada")
plt.title("Función de distribución acumulada")
plt.plot(datos, cdf)
plt.show()
# Gráfico PPF función de distribución inversa
plt.subplot(2, 1, 1)
plt.xlabel("Datos de muestra")
plt.ylabel("Función de distribución inversa")
plt.title("Función de distribución inversa")
plt.plot(datos, ppf)
plt.show()

# %%
from scipy.stats import uniform
import numpy as np
import matplotlib.pyplot as plt
def pdfuniform(x, minimo = 0, maximo = 1):
    resultado = uniform.pdf(x = x, loc = minimo, scale = maximo)
    return resultado
def cdfuniform(x, minimo = 0, maximo = 1):
    resultado = uniform.cdf(x = x, loc = minimo, scale = maximo)
    return resultado
def ppfuniform(x, minimo = 0, maximo = 1):
    resultado = uniform.ppf(q = x, loc = minimo, scale = maximo)
    return resultado
def rvsuniform(x, minimo = 0, maximo = 1):
    resultado = uniform.rvs(size = x, loc = minimo, scale = maximo)
    return resultado

# %%
minimo = 0
maximo = 1 
datos = np.arange(-10, 10, 0.2)
pdfu = pdfuniform(datos, minimo, maximo)
cdfu = cdfuniform(datos, minimo, maximo)
ppfu = ppfuniform(datos, minimo, maximo)
# Grafico PDF función de densidad de probabilidad para datos uniformes
plt.subplot(2,1,1)
plt.xlabel("datos")
plt.ylabel("pdf")
plt.title("Función de densidad de probabilidad para datos uniformes")
plt.plot(datos, pdfu)
plt.show()
# Gráfico CDF función de distribución acumulada con datos uniformes
plt.subplot(2,1,1)
plt.xlabel("datos")
plt.ylabel("cdf")
plt.title("Función de distribución acumulada con datos uniformes")
plt.plot(datos, cdfu)
plt.show()
# Gráfico PPF función de distribución inversa con datos uniformes
plt.subplot(2,1,1)
plt.xlabel("Datos de muestra")
plt.ylabel("Funcion PDF")
plt.title("Función de distribución inversa con datos uniformes")
plt.plot(datos, ppfu)
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
# He estado experimentando un poco con las librerias y llegue a la conclusión de que también puedo lograr el mismo resultado simplificando las funciones, y tomando el arreglo ya hecho por scipy.stats, norm, uniform
# Ahorrando lineas de codigo y haciendo más optimo el resultado.
datos = np.arange(-5, 5, 0.01)
# Para datos normales
pdf = norm.pdf(datos)
plt.figure(figsize=(8, 4))
plt.plot(datos, pdf)
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.title('PDf - distribución normal')
plt.show()

cdf = norm.cdf(datos)
plt.figure(figsize=(8, 4))
plt.plot(datos, cdf)
plt.xlabel('Valor')
plt.ylabel('Función de distribución acumulada')
plt.title('CDF - distribución normal')
plt.show()

ppf = norm.ppf(datos)
plt.figure(figsize=(8, 4))
plt.plot(datos, ppf)
plt.xlabel('Valor')
plt.ylabel('Función de distribución inversa')
plt.title('PPF - distribución normal')
plt.show()

# Para datos uniformes
from scipy.stats import uniform
import numpy as np
import matplotlib.pyplot as plt
datos = np.arange(-5, 5, 0.01)
pdf = uniform.pdf(datos)
plt.figure(figsize=(8, 4))
plt.plot(datos, pdf)
plt.xlabel('Valor')
plt.ylabel('Densidad de probabilidad')
plt.title('PDF - distribución uniforme')
plt.show()

cdf = uniform.cdf(datos)
plt.figure(figsize = (8, 4))
plt.plot(datos, cdf)
plt.xlabel('Valor')
plt.ylabel('CDF - distribución uniforme')
plt.title('CDF - distribución uniforme')
plt.show()

ppf = uniform.ppf(datos)
plt.figure(figsize = (8, 4))
plt.plot(datos, ppf)
plt.xlabel('Valor')
plt.ylabel('PPF - distribución uniforme')
plt.title('PPF - distribución uniforme')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
